# %%
# Defining a function to get the information of each restaurant in hyderabad

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

def get_res_info_hyd(df_hyd, bs_data_hyd, max_restaurants_hyd):
    restaurants_hyd = bs_data_hyd.find_all("div", attrs={"class": "sc-kDgGX fjYwDL"})
    for each_res in restaurants_hyd:
        if len(df_hyd) >= max_restaurants_hyd:
            break  # Stop if we've reached the desired number of restaurants
        
        try:
            name = each_res.find("h4", attrs={"class": "sc-1hp8d8a-0 sc-bpubUI eKeNGz"}).text
            location = each_res.find("p", attrs={"class": "sc-1hez2tp-0 sc-jkPxnQ jKgMiA"}).text
            cuisine = each_res.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr gVSfmH"}).text
            price_for_2 = each_res.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr jIrGje"}).text
            walk_in_offer = each_res.find("div", attrs={"class": "walkin-offer-value"}).text
            rating = each_res.find("div", attrs={"class": "sc-1q7bklc-1 cILgox"}).text
            average_distance = each_res.find("div", attrs={"class": "min-basic-info-right"}).text
            

        except AttributeError:
            continue

        data_dict_hyd = {"Name": name,
                         "Location": location,
                         "Cuisine": cuisine,
                         "Price for 2": price_for_2,
                         "Walk in Offer": walk_in_offer,
                         "Rating": rating,
                         "Average distance": average_distance}

        each_df_hyd = pd.DataFrame(data_dict_hyd, index=[0])
        df_hyd = pd.concat((df_hyd, each_df_hyd), ignore_index=True)
    return df_hyd

# Setup WebDriver
edge_options = Options()
edge_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
service = Service('msedgedriver.exe')
driver = webdriver.Edge(service=service, options=edge_options)

page_link = r"https://www.zomato.com/hyderabad"
driver.get(page_link)

df_hyd = pd.DataFrame()

# Desired number of restaurants to scrape
max_restaurants_hyd = 500

# Scroll and load more content
last_height = driver.execute_script("return document.body.scrollHeight")
while len(df_hyd) < max_restaurants_hyd:
    # Scroll down to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Wait for new content to load

    # Get new page source and parse with BeautifulSoup
    bs_data_hyd = BeautifulSoup(driver.page_source, 'html.parser')
    df_hyd = get_res_info_hyd(df_hyd, bs_data_hyd, max_restaurants_hyd)

    # Check if more content was loaded
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print(f"Total restaurants scraped: {len(df_hyd)}")

driver.quit()
# Out:
# Total restaurants scraped: 500

# %%
df_hyd
# Out:
#                                      Name  \
# 0                              Tashi Cafe
# 1                              Coffee Cup
# 2                                    Ofen
# 3       Shanghai - Flavours of China Town
# 4                               Red Rhino
# ..                                    ...
# 495   Jewel of Nizam - The Golkonda Hotel
# 496                               Cravery
# 497                          Cravery Cafe
# 498                      Sounds & Spirits
# 499  Spice It - ibis Hyderabad HITEC City
#
#                                    Location  \
# 0                  Banjara Hills, Hyderabad
# 1                     Somajiguda, Hyderabad
# 2                  Banjara Hills, Hyderabad
# 3                    S P Road, Secunderabad
# 4                    Hitech City, Hyderabad
# ..                                      ...
# 495   Golkonda Hotel, Masab Tank, Hyderabad
# 496                Jubilee Hills, Hyderabad
# 497           Financial District, Hyderabad
# 498                     Madhapur, Hyderabad
# 499    ibis Hyderabad HITEC City, Hyderabad
#
#                                                Cuisine     Price for 2  \
# 0    North Indian, Pizza, Pasta, Italian, Chinese, ...  ₹2,000 for two
# 1    Cafe, Tea, Beverages, American, Pizza, Burger,...    ₹950 for two
# 2    Cafe, Coffee, Sandwich, Italian, Mexican, Past...  ₹1,200 for two
# 3                                       Chinese, Asian  ₹1,000 for two
# 4    Asian, North Indian, Continental, European, Bu...  ₹2,400 for two
# ..                                                 ...             ...
# 495                                Hyderabadi, Mughlai  ₹5,000 for two
# 496  Cafe, Chinese, BBQ, Continental, Seafood, Ital...    ₹950 for two
# 497  Cafe, Coffee, North Indian, Mughlai, Seafood, ...  ₹1,000 for two
# 498  Finger Food, Continental, Pizza, North Indian,...  ₹1,300 for two
# 499  North Indian, Chinese, Biryani, Desserts, Beve...  ₹1,600 for two
#
#     Walk in Offer Rating Average distance
# 0    Flat 10% OFF    New           5.8 km
# 1    Flat 10% OFF    4.2           6.5 km
# 2    Flat 10% OFF    3.7           6.5 km
# 3    Flat 15% OFF    4.3           8.6 km
# 4    Flat 10% OFF    4.5          12.7 km
# ..            ...    ...              ...
# 495  Flat 10% OFF    4.1           4.9 km
# 496  Flat 10% OFF    4.6             9 km
# 497  Flat 10% OFF    4.4          15.9 km
# 498  Flat 10% OFF    3.9            12 km
# 499  Flat 30% OFF    3.9          13.7 km
#
# [500 rows x 7 columns]

# %%
# Defining a function to get the information of each restaurant in Bangalore

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

def get_res_info_blr(df_blr, bs_data_blr, max_restaurants_blr):
    restaurants_blr = bs_data_blr.find_all("div", attrs={"class": "sc-kDgGX fjYwDL"})
    for each_res_blr in restaurants_blr:
        if len(df_blr) >= max_restaurants_blr:
            break  # Stop if we've reached the desired number of restaurants
        
        try:
            name_blr = each_res_blr.find("h4", attrs={"class": "sc-1hp8d8a-0 sc-bpubUI eKeNGz"}).text
            location_blr = each_res_blr.find("p", attrs={"class": "sc-1hez2tp-0 sc-jkPxnQ jKgMiA"}).text
            cuisine_blr = each_res_blr.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr gVSfmH"}).text
            price_for_2_blr = each_res_blr.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr jIrGje"}).text
            walk_in_offer_blr = each_res_blr.find("div", attrs={"class": "walkin-offer-value"}).text
            rating_blr = each_res_blr.find("div", attrs={"class": "sc-1q7bklc-1 cILgox"}).text
            average_distance_blr = each_res_blr.find("div", attrs={"class": "min-basic-info-right"}).text

        except AttributeError:
            continue

        data_dict_blr = {"Name": name_blr,
                         "Location": location_blr,
                         "Cuisine": cuisine_blr,
                         "Price for 2": price_for_2_blr,
                         "Walk in Offer": walk_in_offer_blr,
                         "Rating": rating_blr,
                         "Average distance": average_distance_blr}

        each_df_blr = pd.DataFrame(data_dict_blr, index=[0])
        df_blr = pd.concat((df_blr, each_df_blr), ignore_index=True)
    return df_blr

# Setup WebDriver
edge_options = Options()
edge_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
service = Service('msedgedriver.exe')
driver = webdriver.Edge(service=service, options=edge_options)

page_link_blr = r"https://www.zomato.com/bangalore"
driver.get(page_link_blr)

df_blr = pd.DataFrame()

# Desired number of restaurants to scrape
max_restaurants_blr = 500

# Scroll and load more content
last_height = driver.execute_script("return document.body.scrollHeight")
while len(df_blr) < max_restaurants_blr:
    # Scroll down to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Wait for new content to load

    # Get new page source and parse with BeautifulSoup
    bs_data_blr = BeautifulSoup(driver.page_source, 'html.parser')
    df_blr = get_res_info_blr(df_blr, bs_data_blr, max_restaurants_blr)

    # Check if more content was loaded
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print(f"Total restaurants scraped: {len(df_blr)}")

driver.quit()
# Out:
# Total restaurants scraped: 500

# %%
df_blr
# Out:
#                        Name  \
# 0            Oney Brewhouse
# 1                Farzi Cafe
# 2     SkyDeck By Sherlock's
# 3                    Maayaa
# 4              Ouzo By Fire
# ..                      ...
# 495            White Garden
# 496  Ambedo Kitchen|Taproom
# 497            Punjab Grill
# 498    Levels Pub & Kitchen
# 499               By Chance
#
#                                               Location  \
# 0                           Cunningham Road, Bangalore
# 1                                   UB City, Bangalore
# 2                                   MG Road, Bangalore
# 3     Prestige Trade Tower, Race Course Road, Banga...
# 4                               Indiranagar, Bangalore
# ..                                                 ...
# 495                            Kalyan Nagar, Bangalore
# 496                                JP Nagar, Bangalore
# 497                          Forum Rex Walk, Bangalore
# 498                                JP Nagar, Bangalore
# 499                            Brigade Road, Bangalore
#
#                                                Cuisine     Price for 2  \
# 0    American, Continental, Italian, South Indian, ...  ₹1,500 for two
# 1                               North Indian, Desserts  ₹1,900 for two
# 2    Continental, Chinese, Finger Food, North India...  ₹1,800 for two
# 3    South Indian, Seafood, Biryani, Kerala, Desser...  ₹1,200 for two
# 4                         Goan, Mangalorean, Beverages  ₹1,000 for two
# ..                                                 ...             ...
# 495  North Indian, Italian, Lebanese, Asian, Contin...  ₹1,600 for two
# 496  Continental, Asian, North Indian, Italian, Piz...  ₹1,500 for two
# 497              North Indian, Kebab, Biryani, Mughlai  ₹2,000 for two
# 498                  Asian, South Indian, North Indian  ₹1,700 for two
# 499                               Italian, Continental  ₹1,500 for two
#
#     Walk in Offer Rating Average distance
# 0    Flat 15% OFF    4.0           1.6 km
# 1    Flat 10% OFF    4.2            168 m
# 2    Flat 15% OFF    4.2           1.5 km
# 3    Flat 15% OFF    4.1           1.7 km
# 4    Flat 10% OFF    4.3           5.1 km
# ..            ...    ...              ...
# 495  Flat 10% OFF    4.3           7.8 km
# 496  Flat 10% OFF    4.5           6.8 km
# 497  Flat 15% OFF    4.3           1.3 km
# 498  Flat 10% OFF    4.5           7.3 km
# 499  Flat 10% OFF    4.2           1.4 km
#
# [500 rows x 7 columns]

# %%
# Defining a function to get the information of each restaurant in Mumbai

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

def get_res_info_mum(df_mum, bs_data_mum, max_restaurants_mum):
    restaurants_mum = bs_data_mum.find_all("div", attrs={"class": "sc-kDgGX fjYwDL"})
    for each_res_mum in restaurants_mum:
        if len(df_mum) >= max_restaurants_mum:
            break  # Stop if we've reached the desired number of restaurants
        
        try:
            name_mum = each_res_mum.find("h4", attrs={"class": "sc-1hp8d8a-0 sc-bpubUI eKeNGz"}).text
            location_mum = each_res_mum.find("p", attrs={"class": "sc-1hez2tp-0 sc-jkPxnQ jKgMiA"}).text
            cuisine_mum = each_res_mum.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr gVSfmH"}).text
            price_for_2_mum = each_res_mum.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr jIrGje"}).text
            walk_in_offer_mum = each_res_mum.find("div", attrs={"class": "walkin-offer-value"}).text
            rating_mum = each_res_mum.find("div", attrs={"class": "sc-1q7bklc-1 cILgox"}).text
            average_distance_mum = each_res_mum.find("div", attrs={"class": "min-basic-info-right"}).text

        except AttributeError:
            continue

        data_dict_mum = {"Name": name_mum,
                         "Location": location_mum,
                         "Cuisine": cuisine_mum,
                         "Price for 2": price_for_2_mum,
                         "Walk in Offer": walk_in_offer_mum,
                         "Rating": rating_mum,
                         "Average distance": average_distance_mum}

        each_df_mum = pd.DataFrame(data_dict_mum, index=[0])
        df_mum = pd.concat((df_mum, each_df_mum), ignore_index=True)
    return df_mum

# Setup WebDriver
edge_options = Options()
edge_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
service = Service('msedgedriver.exe')
driver = webdriver.Edge(service=service, options=edge_options)

page_link_mum = r"https://www.zomato.com/mumbai"
driver.get(page_link_mum)

df_mum = pd.DataFrame()

# Desired number of restaurants to scrape
max_restaurants_mum = 500

# Scroll and load more content
last_height = driver.execute_script("return document.body.scrollHeight")
while len(df_mum) < max_restaurants_mum:
    # Scroll down to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Wait for new content to load

    # Get new page source and parse with BeautifulSoup
    bs_data_mum = BeautifulSoup(driver.page_source, 'html.parser')
    df_mum = get_res_info_mum(df_mum, bs_data_mum, max_restaurants_mum)

    # Check if more content was loaded
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print(f"Total restaurants scraped: {len(df_mum)}")

driver.quit()
# Out:
# Total restaurants scraped: 500

# %%
df_mum
# Out:
#                              Name                                    Location  \
# 0                Not Just Tamasha                         Lower Parel, Mumbai
# 1                  Goa Portuguesa                               Mahim, Mumbai
# 2                           Eight         Palladium Mall, Lower Parel, Mumbai
# 3                         Ishaara         Palladium Mall, Lower Parel, Mumbai
# 4            Therapy Cocktail Bar                                Khar, Mumbai
# ..                            ...                                         ...
# 495     Bustling Brew Bistro Cafe             Wagle Estate, Thane West, Thane
# 496                  On The Docks                                Fort, Mumbai
# 497       Kissa Stories Over Food   Andheri Lokhandwala, Andheri West, Mumbai
# 498  Three 60 Daily Bar & Kitchen               Versova, Andheri West, Mumbai
# 499                 Western Tadka                       Borivali West, Mumbai
#
#                                                Cuisine     Price for 2  \
# 0    Bar Food, Continental, Pasta, Pizza, Asian, Ch...  ₹1,800 for two
# 1    Goan, Portuguese, South Indian, Maharashtrian,...  ₹2,500 for two
# 2                               Asian, Japanese, Sushi  ₹3,500 for two
# 3                North Indian, Mughlai, Kebab, Biryani  ₹1,900 for two
# 4    Bar Food, Chinese, Desserts, Beverages, Pasta,...  ₹1,000 for two
# ..                                                 ...             ...
# 495  Cafe, Beverages, Italian, Chinese, Fast Food, ...    ₹700 for two
# 496  Chinese, Continental, Italian, Pizza, Pasta, N...  ₹1,200 for two
# 497  Asian, Sushi, Italian, Pizza, Modern Indian, B...  ₹1,400 for two
# 498  Bar Food, North Indian, Mughlai, Biryani, Keba...  ₹1,000 for two
# 499                     North Indian, Chinese, Biryani  ₹1,200 for two
#
#     Walk in Offer Rating Average distance
# 0    Flat 20% OFF    New           3.3 km
# 1    Flat 10% OFF    4.5           2.3 km
# 2    Flat 10% OFF    4.6           4.1 km
# 3    Flat 10% OFF    4.7           4.1 km
# 4    Flat 10% OFF    4.2           6.1 km
# ..            ...    ...              ...
# 495  Flat 15% OFF    4.7          21.9 km
# 496  Flat 10% OFF    4.2           9.1 km
# 497  Flat 15% OFF    4.3          14.4 km
# 498  Flat 15% OFF    4.4            13 km
# 499  Flat 10% OFF    4.0            23 km
#
# [500 rows x 7 columns]

# %%
# Defining a function to get the information of each restaurant in Chennai

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

def get_res_info_che(df_che, bs_data_che, max_restaurants_che):
    restaurants_che = bs_data_che.find_all("div", attrs={"class": "sc-kDgGX fjYwDL"})
    for each_res_che in restaurants_che:
        if len(df_che) >= max_restaurants_che:
            break  # Stop if we've reached the desired number of restaurants
        
        try:
            name_che = each_res_che.find("h4", attrs={"class": "sc-1hp8d8a-0 sc-bpubUI eKeNGz"}).text
            location_che = each_res_che.find("p", attrs={"class": "sc-1hez2tp-0 sc-jkPxnQ jKgMiA"}).text
            cuisine_che = each_res_che.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr gVSfmH"}).text
            price_for_2_che = each_res_che.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr jIrGje"}).text
            walk_in_offer_che = each_res_che.find("div", attrs={"class": "walkin-offer-value"}).text
            rating_che = each_res_che.find("div", attrs={"class": "sc-1q7bklc-1 cILgox"}).text
            average_distance_che = each_res_che.find("div", attrs={"class": "min-basic-info-right"}).text

        except AttributeError:
            continue

        data_dict_che = {"Name": name_che,
                         "Location": location_che,
                         "Cuisine": cuisine_che,
                         "Price for 2": price_for_2_che,
                         "Walk in Offer": walk_in_offer_che,
                         "Rating": rating_che,
                         "Average distance": average_distance_che}

        each_df_che = pd.DataFrame(data_dict_che, index=[0])
        df_che = pd.concat((df_che, each_df_che), ignore_index=True)
    return df_che

# Setup WebDriver
edge_options = Options()
edge_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
service = Service('msedgedriver.exe')
driver = webdriver.Edge(service=service, options=edge_options)

page_link_che = r"https://www.zomato.com/chennai"
driver.get(page_link_che)

df_che = pd.DataFrame()

# Desired number of restaurants to scrape
max_restaurants_che = 500

# Scroll and load more content
last_height = driver.execute_script("return document.body.scrollHeight")
while len(df_che) < max_restaurants_che:
    # Scroll down to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Wait for new content to load

    # Get new page source and parse with BeautifulSoup
    bs_data_che = BeautifulSoup(driver.page_source, 'html.parser')
    df_che = get_res_info_che(df_che, bs_data_che, max_restaurants_che)

    # Check if more content was loaded
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print(f"Total restaurants scraped: {len(df_che)}")

driver.quit()
# Out:
# Total restaurants scraped: 500

# %%
df_che
# Out:
#                           Name                                  Location  \
# 0    Sterling By Madras Square                     Nungambakkam, Chennai
# 1                 Dil Se Rasoi                          Kilpauk, Chennai
# 2      Dhaba - Estd 1986 Delhi    Ispahani Centre, Nungambakkam, Chennai
# 3                 Marina Sands                   Ramada, Egmore, Chennai
# 4        Gujraj Veg Restaurant                        Park Town, Chennai
# ..                         ...                                       ...
# 495                 AsianKatha                     Nungambakkam, Chennai
# 496              The Mayflower                  Anna Nagar East, Chennai
# 497                     Trella             Jaag Hotels, T.Nagar, Chennai
# 498                  Surf Turf                          Kovalam, Chennai
# 499               Kipling Cafe   Kipling, East Coast Road (ECR), Chennai
#
#                                                Cuisine     Price for 2  \
# 0    Continental, Italian, Chinese, Pasta, Asian, P...  ₹1,000 for two
# 1    Chinese, North Indian, Street Food, Sandwich, ...  ₹1,000 for two
# 2      North Indian, Mughlai, Biryani, Kebab, Desserts  ₹1,500 for two
# 3             Seafood, North Indian, Chinese, Desserts  ₹1,000 for two
# 4    South Indian, Chinese, North Indian, Thai, Ice...  ₹1,000 for two
# ..                                                 ...             ...
# 495  Japanese, Singaporean, Chinese, Asian, Indones...  ₹1,500 for two
# 496                                        Continental  ₹2,000 for two
# 497  Continental, Fast Food, Asian, Italian, Chines...  ₹1,800 for two
# 498  Continental, Chinese, Italian, Seafood, Desser...    ₹700 for two
# 499  Continental, Asian, North Indian, Chinese, Piz...  ₹1,600 for two
#
#     Walk in Offer Rating Average distance
# 0    Flat 10% OFF    New           3.6 km
# 1    Flat 10% OFF    3.7           2.8 km
# 2    Flat 10% OFF    4.4           3.9 km
# 3    Flat 20% OFF    3.6            983 m
# 4    Flat 10% OFF    3.8            365 m
# ..            ...    ...              ...
# 495  Flat 10% OFF    New           3.6 km
# 496  Flat 10% OFF    New           5.6 km
# 497  Flat 15% OFF    4.2           5.1 km
# 498  Flat 10% OFF    4.1          33.1 km
# 499  Flat 10% OFF    4.1            21 km
#
# [500 rows x 7 columns]

# %%
# Defining a function to get the information of each restaurant in Delhi

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

def get_res_info_del(df_del, bs_data_del, max_restaurants_del):
    restaurants_del = bs_data_del.find_all("div", attrs={"class": "sc-kDgGX fjYwDL"})
    for each_res_del in restaurants_del:
        if len(df_del) >= max_restaurants_del:
            break  # Stop if we've reached the desired number of restaurants
        
        try:
            name_del = each_res_del.find("h4", attrs={"class": "sc-1hp8d8a-0 sc-bpubUI eKeNGz"}).text
            location_del = each_res_del.find("p", attrs={"class": "sc-1hez2tp-0 sc-jkPxnQ jKgMiA"}).text
            cuisine_del = each_res_del.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr gVSfmH"}).text
            price_for_2_del = each_res_del.find("p", attrs={"class": "sc-1hez2tp-0 sc-sVRsr jIrGje"}).text
            walk_in_offer_del = each_res_del.find("div", attrs={"class": "walkin-offer-value"}).text
            rating_del = each_res_del.find("div", attrs={"class": "sc-1q7bklc-1 cILgox"}).text
            average_distance_del = each_res_del.find("div", attrs={"class": "min-basic-info-right"}).text

        except AttributeError:
            walk_in_offer_del = np.nan
            continue

        data_dict_del = {"Name": name_del,
                         "Location": location_del,
                         "Cuisine": cuisine_del,
                         "Price for 2": price_for_2_del,
                         "Walk in Offer": walk_in_offer_del,
                         "Rating": rating_del,
                         "Average distance": average_distance_del}

        each_df_del = pd.DataFrame(data_dict_del, index=[0])
        df_del = pd.concat((df_del, each_df_del), ignore_index=True)
    return df_del

# Setup WebDriver
edge_options = Options()
edge_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
service = Service('msedgedriver.exe')
driver = webdriver.Edge(service=service, options=edge_options)

page_link_del = r"https://www.zomato.com/ncr"
driver.get(page_link_del)

df_del = pd.DataFrame()

# Desired number of restaurants to scrape
max_restaurants_del = 500

# Scroll and load more content
last_height = driver.execute_script("return document.body.scrollHeight")
while len(df_del) < max_restaurants_del:
    # Scroll down to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Wait for new content to load

    # Get new page source and parse with BeautifulSoup
    bs_data_del = BeautifulSoup(driver.page_source, 'html.parser')
    df_del = get_res_info_del(df_del, bs_data_del, max_restaurants_del)

    # Check if more content was loaded
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print(f"Total restaurants scraped: {len(df_del)}")

driver.quit()
# Out:
# Total restaurants scraped: 500

# %%
df_del
# Out:
#                                                Name  \
# 0                           Cé La Vie Kitchen & Bar
# 1                          Out Of The Box Courtyard
# 2                                Lord Of The Drinks
# 3                           The Darzi Bar & Kitchen
# 4    Mount Fuji Japanese Pan Asian Restaurant & Bar
# ..                                              ...
# 495                                      Farzi Cafe
# 496        64/6 -  Country Inn & Suites By Radisson
# 497                                   Laidback Cafe
# 498                                    Cafe Hawkers
# 499                            MardiGras By Uncover
#
#                                               Location  \
# 0            Middle Circle, Connaught Place, New Delhi
# 1            Middle Circle, Connaught Place, New Delhi
# 2             Outer Circle, Connaught Place, New Delhi
# 3            Middle Circle, Connaught Place, New Delhi
# 4            Middle Circle, Connaught Place, New Delhi
# ..                                                 ...
# 495                 Cyber Hub, DLF Cyber City, Gurgaon
# 496   Country Inn & Suites by Carlson, Sahibabad, G...
# 497                 Cyber Hub, DLF Cyber City, Gurgaon
# 498                         Connaught Place, New Delhi
# 499                        Sector 9, Dwarka, New Delhi
#
#                                                Cuisine     Price for 2  \
# 0    North Indian, Mediterranean, Continental, Sush...  ₹2,200 for two
# 1    Continental, North Indian, Italian, Pizza, Chi...  ₹2,200 for two
# 2    Oriental, North Indian, Continental, Italian, ...  ₹2,400 for two
# 3    North Indian, Chinese, Asian, Italian, Mughlai...  ₹2,800 for two
# 4    Japanese, Asian, Chinese, Thai, Sushi, Seafood...  ₹2,400 for two
# ..                                                 ...             ...
# 495           North Indian, Fast Food, Pizza, Desserts  ₹2,000 for two
# 496           North Indian, Chinese, Thai, Continental  ₹3,500 for two
# 497  Asian, Oriental, Continental, Italian, Middle ...  ₹1,900 for two
# 498  North Indian, Chinese, Mexican, Fast Food, Des...  ₹1,600 for two
# 499           North Indian, European, Italian, Turkish  ₹2,000 for two
#
#     Walk in Offer Rating Average distance
# 0    Flat 20% OFF    4.3           1.4 km
# 1    Flat 20% OFF    4.1           1.2 km
# 2    Flat 15% OFF    4.3            937 m
# 3    Flat 25% OFF    4.2           1.4 km
# 4    Flat 25% OFF    4.6           1.4 km
# ..            ...    ...              ...
# 495  Flat 10% OFF    4.3          18.8 km
# 496  Flat 20% OFF    4.6          13.4 km
# 497  Flat 15% OFF    4.6          19.1 km
# 498  Flat 15% OFF    4.2           1.5 km
# 499  Flat 10% OFF    4.3          15.1 km
#
# [500 rows x 7 columns]

# %%
df = pd.DataFrame()

# %%
# Adding all the dataframes to get the final dataframe with restaurants from all cities

# %%
df = pd.concat((df, df_hyd, df_blr, df_mum, df_che, df_del))

# %%
df
# Out:
#                                          Name  \
# 0                                  Tashi Cafe
# 1                                  Coffee Cup
# 2                                        Ofen
# 3           Shanghai - Flavours of China Town
# 4                                   Red Rhino
# ..                                        ...
# 495                                Farzi Cafe
# 496  64/6 -  Country Inn & Suites By Radisson
# 497                             Laidback Cafe
# 498                              Cafe Hawkers
# 499                      MardiGras By Uncover
#
#                                               Location  \
# 0                             Banjara Hills, Hyderabad
# 1                                Somajiguda, Hyderabad
# 2                             Banjara Hills, Hyderabad
# 3                               S P Road, Secunderabad
# 4                               Hitech City, Hyderabad
# ..                                                 ...
# 495                 Cyber Hub, DLF Cyber City, Gurgaon
# 496   Country Inn & Suites by Carlson, Sahibabad, G...
# 497                 Cyber Hub, DLF Cyber City, Gurgaon
# 498                         Connaught Place, New Delhi
# 499                        Sector 9, Dwarka, New Delhi
#
#                                                Cuisine     Price for 2  \
# 0    North Indian, Pizza, Pasta, Italian, Chinese, ...  ₹2,000 for two
# 1    Cafe, Tea, Beverages, American, Pizza, Burger,...    ₹950 for two
# 2    Cafe, Coffee, Sandwich, Italian, Mexican, Past...  ₹1,200 for two
# 3                                       Chinese, Asian  ₹1,000 for two
# 4    Asian, North Indian, Continental, European, Bu...  ₹2,400 for two
# ..                                                 ...             ...
# 495           North Indian, Fast Food, Pizza, Desserts  ₹2,000 for two
# 496           North Indian, Chinese, Thai, Continental  ₹3,500 for two
# 497  Asian, Oriental, Continental, Italian, Middle ...  ₹1,900 for two
# 498  North Indian, Chinese, Mexican, Fast Food, Des...  ₹1,600 for two
# 499           North Indian, European, Italian, Turkish  ₹2,000 for two
#
#     Walk in Offer Rating Average distance
# 0    Flat 10% OFF    New           5.8 km
# 1    Flat 10% OFF    4.2           6.5 km
# 2    Flat 10% OFF    3.7           6.5 km
# 3    Flat 15% OFF    4.3           8.6 km
# 4    Flat 10% OFF    4.5          12.7 km
# ..            ...    ...              ...
# 495  Flat 10% OFF    4.3          18.8 km
# 496  Flat 20% OFF    4.6          13.4 km
# 497  Flat 15% OFF    4.6          19.1 km
# 498  Flat 15% OFF    4.2           1.5 km
# 499  Flat 10% OFF    4.3          15.1 km
#
# [2500 rows x 7 columns]

# %%
df.to_csv("Zomato_Restaurants_raw - Web Scraping Project-2.csv")

# %% [markdown]
# ### Step-2 Data Preparation

# %%
import re
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("Zomato_Restaurants_raw - Web Scraping Project-2.csv")

# %%
dataset
# Out:
#       Unnamed: 0                                      Name  \
# 0              0                                Tashi Cafe
# 1              1                                Coffee Cup
# 2              2                                      Ofen
# 3              3         Shanghai - Flavours of China Town
# 4              4                                 Red Rhino
# ...          ...                                       ...
# 2495         495                                Farzi Cafe
# 2496         496  64/6 -  Country Inn & Suites By Radisson
# 2497         497                             Laidback Cafe
# 2498         498                              Cafe Hawkers
# 2499         499                      MardiGras By Uncover
#
#                                                Location  \
# 0                              Banjara Hills, Hyderabad
# 1                                 Somajiguda, Hyderabad
# 2                              Banjara Hills, Hyderabad
# 3                                S P Road, Secunderabad
# 4                                Hitech City, Hyderabad
# ...                                                 ...
# 2495                 Cyber Hub, DLF Cyber City, Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad, G...
# 2497                 Cyber Hub, DLF Cyber City, Gurgaon
# 2498                         Connaught Place, New Delhi
# 2499                        Sector 9, Dwarka, New Delhi
#
#                                                 Cuisine     Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...  ₹2,000 for two
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...    ₹950 for two
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...  ₹1,200 for two
# 3                                        Chinese, Asian  ₹1,000 for two
# 4     Asian, North Indian, Continental, European, Bu...  ₹2,400 for two
# ...                                                 ...             ...
# 2495           North Indian, Fast Food, Pizza, Desserts  ₹2,000 for two
# 2496           North Indian, Chinese, Thai, Continental  ₹3,500 for two
# 2497  Asian, Oriental, Continental, Italian, Middle ...  ₹1,900 for two
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...  ₹1,600 for two
# 2499           North Indian, European, Italian, Turkish  ₹2,000 for two
#
#      Walk in Offer Rating Average distance
# 0     Flat 10% OFF    New           5.8 km
# 1     Flat 10% OFF    4.2           6.5 km
# 2     Flat 10% OFF    3.7           6.5 km
# 3     Flat 15% OFF    4.3           8.6 km
# 4     Flat 10% OFF    4.5          12.7 km
# ...            ...    ...              ...
# 2495  Flat 10% OFF    4.3          18.8 km
# 2496  Flat 20% OFF    4.6          13.4 km
# 2497  Flat 15% OFF    4.6          19.1 km
# 2498  Flat 15% OFF    4.2           1.5 km
# 2499  Flat 10% OFF    4.3          15.1 km
#
# [2500 rows x 8 columns]

# %%
dataset.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                                Location  \
# 0                              Banjara Hills, Hyderabad
# 1                                 Somajiguda, Hyderabad
# 2                              Banjara Hills, Hyderabad
# 3                                S P Road, Secunderabad
# 4                                Hitech City, Hyderabad
# ...                                                 ...
# 2495                 Cyber Hub, DLF Cyber City, Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad, G...
# 2497                 Cyber Hub, DLF Cyber City, Gurgaon
# 2498                         Connaught Place, New Delhi
# 2499                        Sector 9, Dwarka, New Delhi
#
#                                                 Cuisine     Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...  ₹2,000 for two
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...    ₹950 for two
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...  ₹1,200 for two
# 3                                        Chinese, Asian  ₹1,000 for two
# 4     Asian, North Indian, Continental, European, Bu...  ₹2,400 for two
# ...                                                 ...             ...
# 2495           North Indian, Fast Food, Pizza, Desserts  ₹2,000 for two
# 2496           North Indian, Chinese, Thai, Continental  ₹3,500 for two
# 2497  Asian, Oriental, Continental, Italian, Middle ...  ₹1,900 for two
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...  ₹1,600 for two
# 2499           North Indian, European, Italian, Turkish  ₹2,000 for two
#
#      Walk in Offer Rating Average distance
# 0     Flat 10% OFF    New           5.8 km
# 1     Flat 10% OFF    4.2           6.5 km
# 2     Flat 10% OFF    3.7           6.5 km
# 3     Flat 15% OFF    4.3           8.6 km
# 4     Flat 10% OFF    4.5          12.7 km
# ...            ...    ...              ...
# 2495  Flat 10% OFF    4.3          18.8 km
# 2496  Flat 20% OFF    4.6          13.4 km
# 2497  Flat 15% OFF    4.6          19.1 km
# 2498  Flat 15% OFF    4.2           1.5 km
# 2499  Flat 10% OFF    4.3          15.1 km
#
# [2500 rows x 7 columns]

# %%
# The Rating column does not have any NaN values, but all the data in the column is not numeric

# %%
dataset.isnull().any()
# Out:
# Name                False
# Location            False
# Cuisine             False
# Price for 2         False
# Walk in Offer       False
# Rating              False
# Average distance    False
# dtype: bool

# %%
# Converting all the values to numeric, and force converting the non-numeric values to NaN

# %%
dataset["Rating"] = pd.to_numeric(dataset["Rating"], errors = 'coerce')

# %%
dataset.isnull().any()
# Out:
# Name                False
# Location            False
# Cuisine             False
# Price for 2         False
# Walk in Offer       False
# Rating               True
# Average distance    False
# dtype: bool

# %%
# 165 restaurants have no ratings

# %%
dataset.isnull().sum()
# Out:
# Name                  0
# Location              0
# Cuisine               0
# Price for 2           0
# Walk in Offer         0
# Rating              165
# Average distance      0
# dtype: int64

# %%
rating_data = dataset[["Name", "Price for 2", "Rating"]]

# %%
rating_data[rating_data.isnull().any(axis = 1)]
# Out:
#                            Name     Price for 2  Rating
# 0                    Tashi Cafe  ₹2,000 for two     NaN
# 10                  Masterpiece  ₹3,200 for two     NaN
# 24    Zindagi Sky Bar & Kitchen  ₹3,100 for two     NaN
# 30              Firestone Grill  ₹1,600 for two     NaN
# 31                   Frat House  ₹2,500 for two     NaN
# ...                         ...             ...     ...
# 2352                     Blanca  ₹1,800 for two     NaN
# 2356       Sufiaana  By Cherish  ₹2,000 for two     NaN
# 2423      Ten Twenty Two - 1022  ₹1,600 for two     NaN
# 2455              Litchi Bistro  ₹1,600 for two     NaN
# 2456                      Local  ₹2,500 for two     NaN
#
# [165 rows x 3 columns]

# %%
dataset.dtypes
# Out:
# Name                 object
# Location             object
# Cuisine              object
# Price for 2          object
# Walk in Offer        object
# Rating              float64
# Average distance     object
# dtype: object

# %%
# Filling the NaN values with the median of ratings, since the rating are slighlty skewed and concentrated between 4.2 to 4.5

# %%
dataset['Rating'] = dataset['Rating'].fillna(dataset['Rating'].median())

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                                Location  \
# 0                              Banjara Hills, Hyderabad
# 1                                 Somajiguda, Hyderabad
# 2                              Banjara Hills, Hyderabad
# 3                                S P Road, Secunderabad
# 4                                Hitech City, Hyderabad
# ...                                                 ...
# 2495                 Cyber Hub, DLF Cyber City, Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad, G...
# 2497                 Cyber Hub, DLF Cyber City, Gurgaon
# 2498                         Connaught Place, New Delhi
# 2499                        Sector 9, Dwarka, New Delhi
#
#                                                 Cuisine     Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...  ₹2,000 for two
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...    ₹950 for two
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...  ₹1,200 for two
# 3                                        Chinese, Asian  ₹1,000 for two
# 4     Asian, North Indian, Continental, European, Bu...  ₹2,400 for two
# ...                                                 ...             ...
# 2495           North Indian, Fast Food, Pizza, Desserts  ₹2,000 for two
# 2496           North Indian, Chinese, Thai, Continental  ₹3,500 for two
# 2497  Asian, Oriental, Continental, Italian, Middle ...  ₹1,900 for two
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...  ₹1,600 for two
# 2499           North Indian, European, Italian, Turkish  ₹2,000 for two
#
#      Walk in Offer  Rating Average distance
# 0     Flat 10% OFF     4.3           5.8 km
# 1     Flat 10% OFF     4.2           6.5 km
# 2     Flat 10% OFF     3.7           6.5 km
# 3     Flat 15% OFF     4.3           8.6 km
# 4     Flat 10% OFF     4.5          12.7 km
# ...            ...     ...              ...
# 2495  Flat 10% OFF     4.3          18.8 km
# 2496  Flat 20% OFF     4.6          13.4 km
# 2497  Flat 15% OFF     4.6          19.1 km
# 2498  Flat 15% OFF     4.2           1.5 km
# 2499  Flat 10% OFF     4.3          15.1 km
#
# [2500 rows x 7 columns]

# %%
dataset["Price for 2"] = dataset["Price for 2"].apply(lambda amount : re.sub(r"[^0-9.]", "", amount))

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                                Location  \
# 0                              Banjara Hills, Hyderabad
# 1                                 Somajiguda, Hyderabad
# 2                              Banjara Hills, Hyderabad
# 3                                S P Road, Secunderabad
# 4                                Hitech City, Hyderabad
# ...                                                 ...
# 2495                 Cyber Hub, DLF Cyber City, Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad, G...
# 2497                 Cyber Hub, DLF Cyber City, Gurgaon
# 2498                         Connaught Place, New Delhi
# 2499                        Sector 9, Dwarka, New Delhi
#
#                                                 Cuisine Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...        2000
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...         950
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...        1200
# 3                                        Chinese, Asian        1000
# 4     Asian, North Indian, Continental, European, Bu...        2400
# ...                                                 ...         ...
# 2495           North Indian, Fast Food, Pizza, Desserts        2000
# 2496           North Indian, Chinese, Thai, Continental        3500
# 2497  Asian, Oriental, Continental, Italian, Middle ...        1900
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...        1600
# 2499           North Indian, European, Italian, Turkish        2000
#
#      Walk in Offer  Rating Average distance
# 0     Flat 10% OFF     4.3           5.8 km
# 1     Flat 10% OFF     4.2           6.5 km
# 2     Flat 10% OFF     3.7           6.5 km
# 3     Flat 15% OFF     4.3           8.6 km
# 4     Flat 10% OFF     4.5          12.7 km
# ...            ...     ...              ...
# 2495  Flat 10% OFF     4.3          18.8 km
# 2496  Flat 20% OFF     4.6          13.4 km
# 2497  Flat 15% OFF     4.6          19.1 km
# 2498  Flat 15% OFF     4.2           1.5 km
# 2499  Flat 10% OFF     4.3          15.1 km
#
# [2500 rows x 7 columns]

# %%
dataset["Price for 2"] = dataset["Price for 2"].astype("float")

# %%
dataset.dtypes
# Out:
# Name                 object
# Location             object
# Cuisine              object
# Price for 2         float64
# Walk in Offer        object
# Rating              float64
# Average distance     object
# dtype: object

# %%
dataset["Walk in Offer"] = dataset["Walk in Offer"].apply(lambda amount : re.sub(r"[^0-9.]", "", amount))

# %%
dataset["Walk in Offer"] = dataset["Walk in Offer"].astype("float")

# %%
dataset.dtypes
# Out:
# Name                 object
# Location             object
# Cuisine              object
# Price for 2         float64
# Walk in Offer       float64
# Rating              float64
# Average distance     object
# dtype: object

# %%
dataset["Average distance"] = dataset["Average distance"].apply(lambda amount : re.sub(r"[^0-9.]", "", amount))

# %%
dataset["Average distance"] = dataset["Average distance"].astype("float")

# %%
def convert_to_km(value):
    if value >= 100:  # assuming all values >= 100 are in meters
        value = value / 1000
    return round(value, 1)

# %%
dataset['Average distance'] = dataset['Average distance'].apply(convert_to_km)

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                                Location  \
# 0                              Banjara Hills, Hyderabad
# 1                                 Somajiguda, Hyderabad
# 2                              Banjara Hills, Hyderabad
# 3                                S P Road, Secunderabad
# 4                                Hitech City, Hyderabad
# ...                                                 ...
# 2495                 Cyber Hub, DLF Cyber City, Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad, G...
# 2497                 Cyber Hub, DLF Cyber City, Gurgaon
# 2498                         Connaught Place, New Delhi
# 2499                        Sector 9, Dwarka, New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance
# 0              10.0     4.3               5.8
# 1              10.0     4.2               6.5
# 2              10.0     3.7               6.5
# 3              15.0     4.3               8.6
# 4              10.0     4.5              12.7
# ...             ...     ...               ...
# 2495           10.0     4.3              18.8
# 2496           20.0     4.6              13.4
# 2497           15.0     4.6              19.1
# 2498           15.0     4.2               1.5
# 2499           10.0     4.3              15.1
#
# [2500 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# Name                 object
# Location             object
# Cuisine              object
# Price for 2         float64
# Walk in Offer       float64
# Rating              float64
# Average distance    float64
# dtype: object

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                                Location  \
# 0                              Banjara Hills, Hyderabad
# 1                                 Somajiguda, Hyderabad
# 2                              Banjara Hills, Hyderabad
# 3                                S P Road, Secunderabad
# 4                                Hitech City, Hyderabad
# ...                                                 ...
# 2495                 Cyber Hub, DLF Cyber City, Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad, G...
# 2497                 Cyber Hub, DLF Cyber City, Gurgaon
# 2498                         Connaught Place, New Delhi
# 2499                        Sector 9, Dwarka, New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance
# 0              10.0     4.3               5.8
# 1              10.0     4.2               6.5
# 2              10.0     3.7               6.5
# 3              15.0     4.3               8.6
# 4              10.0     4.5              12.7
# ...             ...     ...               ...
# 2495           10.0     4.3              18.8
# 2496           20.0     4.6              13.4
# 2497           15.0     4.6              19.1
# 2498           15.0     4.2               1.5
# 2499           10.0     4.3              15.1
#
# [2500 rows x 7 columns]

# %%
dataset[['Area', 'City']] = dataset['Location'].str.rsplit(',', n = 1, expand = True)

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                                Location  \
# 0                              Banjara Hills, Hyderabad
# 1                                 Somajiguda, Hyderabad
# 2                              Banjara Hills, Hyderabad
# 3                                S P Road, Secunderabad
# 4                                Hitech City, Hyderabad
# ...                                                 ...
# 2495                 Cyber Hub, DLF Cyber City, Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad, G...
# 2497                 Cyber Hub, DLF Cyber City, Gurgaon
# 2498                         Connaught Place, New Delhi
# 2499                        Sector 9, Dwarka, New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance  \
# 0              10.0     4.3               5.8
# 1              10.0     4.2               6.5
# 2              10.0     3.7               6.5
# 3              15.0     4.3               8.6
# 4              10.0     4.5              12.7
# ...             ...     ...               ...
# 2495           10.0     4.3              18.8
# 2496           20.0     4.6              13.4
# 2497           15.0     4.6              19.1
# 2498           15.0     4.2               1.5
# 2499           10.0     4.3              15.1
#
#                                              Area           City
# 0                                   Banjara Hills      Hyderabad
# 1                                      Somajiguda      Hyderabad
# 2                                   Banjara Hills      Hyderabad
# 3                                        S P Road   Secunderabad
# 4                                     Hitech City      Hyderabad
# ...                                           ...            ...
# 2495                    Cyber Hub, DLF Cyber City        Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad      Ghaziabad
# 2497                    Cyber Hub, DLF Cyber City        Gurgaon
# 2498                              Connaught Place      New Delhi
# 2499                             Sector 9, Dwarka      New Delhi
#
# [2500 rows x 9 columns]

# %%
dataset = dataset[["Name", "Area", "City", "Cuisine", "Price for 2", "Walk in Offer", "Rating", "Average distance", "Location"]]

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                              Area           City  \
# 0                                   Banjara Hills      Hyderabad
# 1                                      Somajiguda      Hyderabad
# 2                                   Banjara Hills      Hyderabad
# 3                                        S P Road   Secunderabad
# 4                                     Hitech City      Hyderabad
# ...                                           ...            ...
# 2495                    Cyber Hub, DLF Cyber City        Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad      Ghaziabad
# 2497                    Cyber Hub, DLF Cyber City        Gurgaon
# 2498                              Connaught Place      New Delhi
# 2499                             Sector 9, Dwarka      New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance  \
# 0              10.0     4.3               5.8
# 1              10.0     4.2               6.5
# 2              10.0     3.7               6.5
# 3              15.0     4.3               8.6
# 4              10.0     4.5              12.7
# ...             ...     ...               ...
# 2495           10.0     4.3              18.8
# 2496           20.0     4.6              13.4
# 2497           15.0     4.6              19.1
# 2498           15.0     4.2               1.5
# 2499           10.0     4.3              15.1
#
#                                                Location
# 0                              Banjara Hills, Hyderabad
# 1                                 Somajiguda, Hyderabad
# 2                              Banjara Hills, Hyderabad
# 3                                S P Road, Secunderabad
# 4                                Hitech City, Hyderabad
# ...                                                 ...
# 2495                 Cyber Hub, DLF Cyber City, Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad, G...
# 2497                 Cyber Hub, DLF Cyber City, Gurgaon
# 2498                         Connaught Place, New Delhi
# 2499                        Sector 9, Dwarka, New Delhi
#
# [2500 rows x 9 columns]

# %%
dataset.drop("Location", axis = 1, inplace = True)
# Out:
# C:\Users\Anura\AppData\Local\Temp\ipykernel_6960\2030622665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop("Location", axis = 1, inplace = True)

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                              Area           City  \
# 0                                   Banjara Hills      Hyderabad
# 1                                      Somajiguda      Hyderabad
# 2                                   Banjara Hills      Hyderabad
# 3                                        S P Road   Secunderabad
# 4                                     Hitech City      Hyderabad
# ...                                           ...            ...
# 2495                    Cyber Hub, DLF Cyber City        Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad      Ghaziabad
# 2497                    Cyber Hub, DLF Cyber City        Gurgaon
# 2498                              Connaught Place      New Delhi
# 2499                             Sector 9, Dwarka      New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance
# 0              10.0     4.3               5.8
# 1              10.0     4.2               6.5
# 2              10.0     3.7               6.5
# 3              15.0     4.3               8.6
# 4              10.0     4.5              12.7
# ...             ...     ...               ...
# 2495           10.0     4.3              18.8
# 2496           20.0     4.6              13.4
# 2497           15.0     4.6              19.1
# 2498           15.0     4.2               1.5
# 2499           10.0     4.3              15.1
#
# [2500 rows x 8 columns]

# %%
dataset['Restaurant type'] = dataset['Cuisine'].str.split(',').str[0]

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                              Area           City  \
# 0                                   Banjara Hills      Hyderabad
# 1                                      Somajiguda      Hyderabad
# 2                                   Banjara Hills      Hyderabad
# 3                                        S P Road   Secunderabad
# 4                                     Hitech City      Hyderabad
# ...                                           ...            ...
# 2495                    Cyber Hub, DLF Cyber City        Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad      Ghaziabad
# 2497                    Cyber Hub, DLF Cyber City        Gurgaon
# 2498                              Connaught Place      New Delhi
# 2499                             Sector 9, Dwarka      New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance Restaurant type
# 0              10.0     4.3               5.8    North Indian
# 1              10.0     4.2               6.5            Cafe
# 2              10.0     3.7               6.5            Cafe
# 3              15.0     4.3               8.6         Chinese
# 4              10.0     4.5              12.7           Asian
# ...             ...     ...               ...             ...
# 2495           10.0     4.3              18.8    North Indian
# 2496           20.0     4.6              13.4    North Indian
# 2497           15.0     4.6              19.1           Asian
# 2498           15.0     4.2               1.5    North Indian
# 2499           10.0     4.3              15.1    North Indian
#
# [2500 rows x 9 columns]

# %%
dataset["Restaurant type"].value_counts()
# Out:
# Restaurant type
# North Indian      736
# Continental       320
# Asian             209
# Cafe              143
# Chinese           135
# South Indian      126
# Bar Food          112
# Italian            96
# Finger Food        59
# Pizza              50
# European           48
# Modern Indian      47
# BBQ                37
# American           36
# Andhra             35
# Japanese           28
# Mediterranean      23
# Sushi              22
# Seafood            18
# Biryani            18
# Korean             17
# Mexican            14
# Goan               12
# Coffee             11
# Salad              11
# Oriental           10
# Middle Eastern      8
# Fast Food           8
# Thai                8
# Bakery              8
# Arabian             8
# Turkish             7
# North Eastern       7
# Tibetan             6
# Desserts            6
# Hyderabadi          6
# Burger              6
# French              5
# Sandwich            4
# Vietnamese          4
# Mughlai             4
# Greek               4
# Moroccan            3
# Street Food         3
# Bengali             3
# Awadhi              3
# Nepalese            3
# Mangalorean         3
# Pasta               3
# Healthy Food        2
# Parsi               2
# Mandi               2
# Peruvian            1
# Name: count, dtype: int64

# %%
# Define a mapping of restaurant types to dining categories
dining_categories = {'Casual Dining': ['Cafe', 'Pizza', 'Bakery', 'Sandwich', 'Fast Food', 'Coffee'],
                     'Fine Dining': ['Italian', 'French', 'Modern Indian', 'European', 'Japanese','Greek', 'Mediterranean', 'Lebanese', 'Middle Eastern', 'Moroccan'],
                     'Regional Dining': ['North Indian', 'South Indian', 'Andhra', 'Goan', 'Mughlai','Biryani', 'Tamil', 'North Eastern', 'Tibetan'],
                     'Specialty Dining': ['BBQ', 'Sushi', 'Seafood', 'Korean', 'Thai', 'Vietnamese','Mexican', 'Oriental'],
                     'Thematic Dining': ['Continental', 'Asian', 'Chinese', 'Bar Food', 'American','Finger Food', 'Salad']}

# Create a reverse mapping for quick lookup
type_to_category = {type_: category for category, types in dining_categories.items() for type_ in types}

# Apply the lambda function to create a new column for dining type
dataset['Type of Dining'] = dataset['Restaurant type'].apply(lambda x: type_to_category.get(x, 'Other'))

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                              Area           City  \
# 0                                   Banjara Hills      Hyderabad
# 1                                      Somajiguda      Hyderabad
# 2                                   Banjara Hills      Hyderabad
# 3                                        S P Road   Secunderabad
# 4                                     Hitech City      Hyderabad
# ...                                           ...            ...
# 2495                    Cyber Hub, DLF Cyber City        Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad      Ghaziabad
# 2497                    Cyber Hub, DLF Cyber City        Gurgaon
# 2498                              Connaught Place      New Delhi
# 2499                             Sector 9, Dwarka      New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance Restaurant type   Type of Dining
# 0              10.0     4.3               5.8    North Indian  Regional Dining
# 1              10.0     4.2               6.5            Cafe    Casual Dining
# 2              10.0     3.7               6.5            Cafe    Casual Dining
# 3              15.0     4.3               8.6         Chinese  Thematic Dining
# 4              10.0     4.5              12.7           Asian  Thematic Dining
# ...             ...     ...               ...             ...              ...
# 2495           10.0     4.3              18.8    North Indian  Regional Dining
# 2496           20.0     4.6              13.4    North Indian  Regional Dining
# 2497           15.0     4.6              19.1           Asian  Thematic Dining
# 2498           15.0     4.2               1.5    North Indian  Regional Dining
# 2499           10.0     4.3              15.1    North Indian  Regional Dining
#
# [2500 rows x 10 columns]

# %%
dataset.drop("Restaurant type", axis = 1, inplace = True)

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                              Area           City  \
# 0                                   Banjara Hills      Hyderabad
# 1                                      Somajiguda      Hyderabad
# 2                                   Banjara Hills      Hyderabad
# 3                                        S P Road   Secunderabad
# 4                                     Hitech City      Hyderabad
# ...                                           ...            ...
# 2495                    Cyber Hub, DLF Cyber City        Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad      Ghaziabad
# 2497                    Cyber Hub, DLF Cyber City        Gurgaon
# 2498                              Connaught Place      New Delhi
# 2499                             Sector 9, Dwarka      New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance   Type of Dining
# 0              10.0     4.3               5.8  Regional Dining
# 1              10.0     4.2               6.5    Casual Dining
# 2              10.0     3.7               6.5    Casual Dining
# 3              15.0     4.3               8.6  Thematic Dining
# 4              10.0     4.5              12.7  Thematic Dining
# ...             ...     ...               ...              ...
# 2495           10.0     4.3              18.8  Regional Dining
# 2496           20.0     4.6              13.4  Regional Dining
# 2497           15.0     4.6              19.1  Thematic Dining
# 2498           15.0     4.2               1.5  Regional Dining
# 2499           10.0     4.3              15.1  Regional Dining
#
# [2500 rows x 9 columns]

# %%
dataset.rename(columns = {'Average distance':'Average distance from City-Center'}, inplace = True)

# %%
dataset
# Out:
#                                           Name  \
# 0                                   Tashi Cafe
# 1                                   Coffee Cup
# 2                                         Ofen
# 3            Shanghai - Flavours of China Town
# 4                                    Red Rhino
# ...                                        ...
# 2495                                Farzi Cafe
# 2496  64/6 -  Country Inn & Suites By Radisson
# 2497                             Laidback Cafe
# 2498                              Cafe Hawkers
# 2499                      MardiGras By Uncover
#
#                                              Area           City  \
# 0                                   Banjara Hills      Hyderabad
# 1                                      Somajiguda      Hyderabad
# 2                                   Banjara Hills      Hyderabad
# 3                                        S P Road   Secunderabad
# 4                                     Hitech City      Hyderabad
# ...                                           ...            ...
# 2495                    Cyber Hub, DLF Cyber City        Gurgaon
# 2496   Country Inn & Suites by Carlson, Sahibabad      Ghaziabad
# 2497                    Cyber Hub, DLF Cyber City        Gurgaon
# 2498                              Connaught Place      New Delhi
# 2499                             Sector 9, Dwarka      New Delhi
#
#                                                 Cuisine  Price for 2  \
# 0     North Indian, Pizza, Pasta, Italian, Chinese, ...       2000.0
# 1     Cafe, Tea, Beverages, American, Pizza, Burger,...        950.0
# 2     Cafe, Coffee, Sandwich, Italian, Mexican, Past...       1200.0
# 3                                        Chinese, Asian       1000.0
# 4     Asian, North Indian, Continental, European, Bu...       2400.0
# ...                                                 ...          ...
# 2495           North Indian, Fast Food, Pizza, Desserts       2000.0
# 2496           North Indian, Chinese, Thai, Continental       3500.0
# 2497  Asian, Oriental, Continental, Italian, Middle ...       1900.0
# 2498  North Indian, Chinese, Mexican, Fast Food, Des...       1600.0
# 2499           North Indian, European, Italian, Turkish       2000.0
#
#       Walk in Offer  Rating  Average distance from City-Center  \
# 0              10.0     4.3                                5.8
# 1              10.0     4.2                                6.5
# 2              10.0     3.7                                6.5
# 3              15.0     4.3                                8.6
# 4              10.0     4.5                               12.7
# ...             ...     ...                                ...
# 2495           10.0     4.3                               18.8
# 2496           20.0     4.6                               13.4
# 2497           15.0     4.6                               19.1
# 2498           15.0     4.2                                1.5
# 2499           10.0     4.3                               15.1
#
#        Type of Dining
# 0     Regional Dining
# 1       Casual Dining
# 2       Casual Dining
# 3     Thematic Dining
# 4     Thematic Dining
# ...               ...
# 2495  Regional Dining
# 2496  Regional Dining
# 2497  Thematic Dining
# 2498  Regional Dining
# 2499  Regional Dining
#
# [2500 rows x 9 columns]

# %%
dataset.to_csv("30-08-2024-Zomato-cleaned.csv")
